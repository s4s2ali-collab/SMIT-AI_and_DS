# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data File: loan-train.csv

# %%
data_loan = pd.read_csv(r"G:\Jupyter Notebook\Practice Data Files\loan-train.csv")
data_loan
# Out:
#        Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0     LP001002    Male      No          0      Graduate            No
# 1     LP001003    Male     Yes          1      Graduate            No
# 2     LP001005    Male     Yes          0      Graduate           Yes
# 3     LP001006    Male     Yes          0  Not Graduate            No
# 4     LP001008    Male      No          0      Graduate            No
# ...        ...     ...     ...        ...           ...           ...
# 1609  LP009965    Male      No         3+      Graduate           Yes
# 1610  LP009966    Male     Yes          0      Graduate            No
# 1611  LP009970    Male     Yes         3+  Not Graduate           Yes
# 1612  LP009977  Female     Yes          2      Graduate           Yes
# 1613  LP009996  Female     Yes          2      Graduate            No
#
#       ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data_loan.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
data_loan.tail()
# Out:
#        Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1609  LP009965    Male      No         3+      Graduate           Yes
# 1610  LP009966    Male     Yes          0      Graduate            No
# 1611  LP009970    Male     Yes         3+  Not Graduate           Yes
# 1612  LP009977  Female     Yes          2      Graduate           Yes
# 1613  LP009996  Female     Yes          2      Graduate            No
#
#       ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1609            13658             9822.0       323.0             180.0
# 1610            13683             2223.0       182.0             360.0
# 1611            19409              768.0       222.0             360.0
# 1612             8997             1354.0       355.0             360.0
# 1613            19858             6305.0       463.0             240.0
#
#       Credit_History Property_Area Loan_Status
# 1609             0.0         Urban           N
# ...

# %%
data_loan.shape
# Out:
# (1614, 13)

# %%
data_loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1614 entries, 0 to 1613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            1614 non-null   object
#  1   Gender             1601 non-null   object
#  2   Married            1611 non-null   object
#  3   Dependents         1599 non-null   object
#  4   Education          1614 non-null   object
#  5   Self_Employed      1582 non-null   object
#  6   ApplicantIncome    1614 non-null   int64
#  7   CoapplicantIncome  1614 non-null   float64
#  8   LoanAmount         1592 non-null   float64
#  9   Loan_Amount_Term   1600 non-null   float64
#  10  Credit_History     1564 non-null   float64
#  11  Property_Area      1614 non-null   object
#  12  Loan_Status        1614 non-null   object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 164.1+ KB

# %%
data_loan.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome   LoanAmount  Loan_Amount_Term  \
# count      1614.000000        1614.000000  1592.000000       1600.000000
# mean       8746.304833        3658.722999   218.846734        290.475000
# std        6249.885122        3291.745935   133.623293         81.899735
# min         150.000000           0.000000     9.000000         12.000000
# 25%        3675.250000         986.250000   112.000000        240.000000
# 50%        7045.000000        2941.500000   180.000000        360.000000
# 75%       13251.000000        5893.000000   324.000000        360.000000
# max       81000.000000       41667.000000   700.000000        480.000000
#
#        Credit_History
# count      1564.00000
# mean          0.63555
# std           0.48143
# min           0.00000
# 25%           0.00000
# 50%           1.00000
# 75%           1.00000
# max           1.00000

# %%
data_loan.duplicated().sum()
# Out:
# np.int64(0)

# %%
data_loan.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data_loan.Gender.unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
data_loan.Gender.nunique()
# Out:
# 2

# %%
data_loan.Married.unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
data_loan.Dependents.unique()
# Out:
# array(['0', '1', '2', '3+', nan], dtype=object)

# %%
data_loan.Dependents.nunique()
# Out:
# 4

# %%
data_loan.Self_Employed.unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
data_loan.LoanAmount.unique()
# Out:
# array([ nan, 128.,  66., 120., 141., 267.,  95., 158., 168., 349.,  70.,
#        109., 200., 114.,  17., 125., 100.,  76., 133., 115., 104., 315.,
#        116., 112., 151., 191., 122., 110.,  35., 201.,  74., 106., 320.,
#        144., 184.,  80.,  47.,  75., 134.,  96.,  88.,  44., 286.,  97.,
#        135., 180.,  99., 165., 258., 126., 312., 136., 172.,  81., 187.,
#        113., 176., 130., 111., 167., 265.,  50., 210., 175., 131., 188.,
#         25., 137., 160., 225., 216.,  94., 139., 152., 118., 185., 154.,
#         85., 259., 194.,  93., 370., 182., 650., 102., 290.,  84., 242.,
#        129.,  30., 244., 600., 255.,  98., 275., 121.,  63., 700.,  87.,
#        101., 495.,  67.,  73., 260., 108.,  58.,  48., 164., 170.,  83.,
#         90., 166., 124.,  55.,  59., 127., 214., 240.,  72.,  60., 138.,
#         42., 280., 140., 155., 123., 279., 192., 304., 330., 150., 207.,
#        436.,  78.,  54.,  89., 143., 105., 132., 480.,  56., 159., 300.,
# ...

# %%
data_loan.LoanAmount.nunique()
# Out:
# 461

# %%
data_loan.Loan_Amount_Term.unique()
# Out:
# array([360., 120., 240.,  nan, 180.,  60., 300., 480.,  36.,  84.,  12.])

# %%
data_loan.Loan_Amount_Term.nunique()
# Out:
# 10

# %%
data_loan.Credit_History.unique()
# Out:
# array([ 1.,  0., nan])

# %%
data_loan.Credit_History.nunique()
# Out:
# 2

# %%
data_loan.Gender.value_counts()
# Out:
# Gender
# Male      980
# Female    621
# Name: count, dtype: int64

# %%
data_loan.Married.value_counts()
# Out:
# Married
# Yes    925
# No     686
# Name: count, dtype: int64

# %%
data_loan.Dependents.value_counts()
# Out:
# Dependents
# 0     619
# 1     341
# 2     336
# 3+    303
# Name: count, dtype: int64

# %%
data_loan.Self_Employed.value_counts()
# Out:
# Self_Employed
# No     999
# Yes    583
# Name: count, dtype: int64

# %%
data_loan.Self_Employed.mode()
# Out:
# 0    No
# Name: Self_Employed, dtype: object

# %%
data_loan.Gender.fillna(data_loan.Gender.mode()[0], inplace=True)
data_loan.Married.fillna(data_loan.Married.mode()[0], inplace=True)
data_loan.Dependents.fillna(data_loan.Dependents.mode()[0], inplace=True)
data_loan.Self_Employed.fillna(data_loan.Self_Employed.mode()[0], inplace=True)
data_loan.LoanAmount.fillna(data_loan.LoanAmount.mean(), inplace=True)
data_loan.Loan_Amount_Term.fillna(data_loan.Loan_Amount_Term.mean(), inplace=True)
data_loan.Credit_History.fillna(data_loan.Credit_History.mode()[0], inplace=True)
data_loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1614 entries, 0 to 1613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            1614 non-null   object
#  1   Gender             1614 non-null   object
#  2   Married            1614 non-null   object
#  3   Dependents         1614 non-null   object
#  4   Education          1614 non-null   object
#  5   Self_Employed      1614 non-null   object
#  6   ApplicantIncome    1614 non-null   int64
#  7   CoapplicantIncome  1614 non-null   float64
#  8   LoanAmount         1614 non-null   float64
#  9   Loan_Amount_Term   1614 non-null   float64
#  10  Credit_History     1614 non-null   float64
#  11  Property_Area      1614 non-null   object
#  12  Loan_Status        1614 non-null   object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 164.1+ KB
# ...

# %%
data_loan.isna().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
plt.hist(data_loan.ApplicantIncome)
# Out:
# (array([901., 475., 231.,   0.,   4.,   0.,   1.,   1.,   0.,   1.]),
#  array([  150.,  8235., 16320., 24405., 32490., 40575., 48660., 56745.,
#         64830., 72915., 81000.]),
#  <BarContainer object of 10 artists>)

# %%
data_loan["Income_category"] = pd.cut(data_loan.ApplicantIncome,bins=[2500,5000,7500,10000,12500,15000,17500,20000,22500,25000,27500],
                                     labels=["0-2.5k","2.5k-5k","5k-7.5k","7.5k-10k","10k-12.5k","12.5k-15k","15k-17.5k","17.5k-20k","20k-22.5k","22.5k-25k"])
Income_category_Freq = data_loan.Income_category.value_counts()
Income_category_Freq
# Out:
# Income_category
# 0-2.5k       457
# 2.5k-5k      229
# 5k-7.5k      191
# 10k-12.5k    152
# 15k-17.5k    152
# 12.5k-15k    134
# 7.5k-10k     131
# 17.5k-20k      4
# 20k-22.5k      1
# 22.5k-25k      0
# Name: count, dtype: int64

# %%
data_loan.ApplicantIncome.min(), data_loan.ApplicantIncome.max(), data_loan.ApplicantIncome.mean()
# Out:
# (150, 81000, np.float64(8746.304832713755))

# %%
Income_category_Freq.plot(kind="bar")
# Out:
# <Axes: xlabel='Income_category'>

# %%
data_loan.Married.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Married'>

# %%
data_loan.Education.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Education'>

# %%
data_loan.Self_Employed.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Self_Employed'>

# %%
data_loan.Property_Area.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Property_Area'>

# %%
data_loan.Loan_Status.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
data_loan[["Gender", "Loan_Status"]].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Gender,Loan_Status'>

# %%
data_loan.Gender.value_counts().plot(kind="pie", autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
data_loan.CoapplicantIncome.value_counts()
# Out:
# CoapplicantIncome
# 0.0       273
# 1666.0      5
# 2500.0      5
# 2083.0      5
# 5625.0      4
#          ...
# 2972.0      1
# 5414.0      1
# 7714.0      1
# 6471.0      1
# 6305.0      1
# Name: count, Length: 1206, dtype: int64

# %%
data_loan.CoapplicantIncome.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
data_loan.CoapplicantIncome.min(), data_loan.CoapplicantIncome.max(), data_loan.CoapplicantIncome.mean()
# Out:
# (0.0, 41667.0, np.float64(3658.722998753804))

# %%
data_loan["Co_Income_category"] = pd.cut(data_loan.CoapplicantIncome,bins=[5000,10000,15000,20000,25000,30500,35000,40000,45000],
                                     labels=["0-5k","5k-10k","10k-15k","15k-20k","20k-25k","25k-30k","30k-35k","35k-40k"])
Co_Income_category_Freq = data_loan.Co_Income_category.value_counts()
Co_Income_category_Freq
# Out:
# Co_Income_category
# 0-5k       512
# 5k-10k       2
# 10k-15k      2
# 25k-30k      1
# 35k-40k      1
# 15k-20k      0
# 20k-25k      0
# 30k-35k      0
# Name: count, dtype: int64

# %%
Co_Income_category_Freq.plot(kind="barh")
# Out:
# <Axes: ylabel='Co_Income_category'>

# %%
frequency_table = pd.DataFrame({
    'Income': data_loan['Income_category'].value_counts(),
    'Co-Income': data_loan['Co_Income_category'].value_counts()
})

# %%
frequency_table.plot(kind="bar", figsize=(8, 5), width=0.8, rot=0)
# Out:
# <Axes: >

# %%
frequency_table.plot(kind="barh", figsize=(8, 5), width=0.8, rot=0)
# Out:
# <Axes: >

# %% [markdown]
# # Data File: adult.csv

# %%
data_adult = pd.read_csv(r"G:\Jupyter Notebook\Practice Data Files\adult.csv")
data_adult
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
data_adult.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
data_adult.tail()
# Out:
#        age     workclass  fnlwgt   education  educational-num  \
# 48837   27       Private  257302  Assoc-acdm               12
# 48838   40       Private  154374     HS-grad                9
# 48839   58       Private  151910     HS-grad                9
# 48840   22       Private  201490     HS-grad                9
# 48841   52  Self-emp-inc  287927     HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 48837             0             0              38  United-States  <=50K
# ...

# %%
data_adult.shape
# Out:
# (48842, 15)

# %%
data_adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
data_adult.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
data_adult.duplicated().sum()
# Out:
# np.int64(52)

# %%
clean_data_adult = data_adult.drop_duplicates()

# %%
clean_data_adult
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
clean_data_adult.duplicated().sum()
# Out:
# np.int64(0)

# %%
clean_data_adult.isna().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
clean_data_adult.workclass.unique()
# Out:
# array(['Private', 'Local-gov', '?', 'Self-emp-not-inc', 'Federal-gov',
#        'State-gov', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
clean_data_adult.workclass.nunique()
# Out:
# 9

# %%
clean_data_adult.workclass.value_counts()
# Out:
# workclass
# Private             33860
# Self-emp-not-inc     3861
# Local-gov            3136
# ?                    2795
# State-gov            1981
# Self-emp-inc         1694
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
clean_data_adult.education.unique()
# Out:
# array(['11th', 'HS-grad', 'Assoc-acdm', 'Some-college', '10th',
#        'Prof-school', '7th-8th', 'Bachelors', 'Masters', 'Doctorate',
#        '5th-6th', 'Assoc-voc', '9th', '12th', '1st-4th', 'Preschool'],
#       dtype=object)

# %%
clean_data_adult.education.nunique()
# Out:
# 16

# %%
clean_data_adult.education.value_counts()
# Out:
# education
# HS-grad         15770
# Some-college    10863
# Bachelors        8013
# Masters          2656
# Assoc-voc        2060
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           954
# Prof-school       834
# 9th               756
# 12th              655
# Doctorate         594
# 5th-6th           507
# 1st-4th           245
# Preschool          81
# Name: count, dtype: int64

# %%
clean_data_adult.marital-status.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12064\2071336728.py in ?()
# ----> 1 clean_data_adult.marital-status.unique()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'marital'

# %%
clean_data_adult.rename(columns={"marital-status":"marital_status"}, inplace=True)
# Out:
# C:\Users\Shoukat Shadat Ali\AppData\Local\Temp\ipykernel_12064\3902317501.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data_adult.rename(columns={"marital-status":"marital_status"}, inplace=True)

# %%
clean_data_adult.marital_status
# Out:
# 0             Never-married
# 1        Married-civ-spouse
# 2        Married-civ-spouse
# 3        Married-civ-spouse
# 4             Never-married
#                 ...
# 48837    Married-civ-spouse
# 48838    Married-civ-spouse
# 48839               Widowed
# 48840         Never-married
# 48841    Married-civ-spouse
# Name: marital_status, Length: 48790, dtype: object

# %%
clean_data_adult.marital_status.value_counts()
# Out:
# marital_status
# Married-civ-spouse       22366
# Never-married            16082
# Divorced                  6630
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      627
# Married-AF-spouse           37
# Name: count, dtype: int64

# %%
clean_data_adult.rename(columns={"educational-num":"educational_num"}, inplace=True)
clean_data_adult.rename(columns={"capital-gain":"capital_gain"}, inplace=True)
clean_data_adult.rename(columns={"capital-loss":"capital_loss"}, inplace=True)
clean_data_adult.rename(columns={"hours-per-week":"hours_per_week"}, inplace=True)
clean_data_adult.rename(columns={"native-country":"native_country"}, inplace=True)
# Out:
# C:\Users\Shoukat Shadat Ali\AppData\Local\Temp\ipykernel_12064\1482433130.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data_adult.rename(columns={"educational-num":"educational_num"}, inplace=True)
# C:\Users\Shoukat Shadat Ali\AppData\Local\Temp\ipykernel_12064\1482433130.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data_adult.rename(columns={"capital-gain":"capital_gain"}, inplace=True)
# C:\Users\Shoukat Shadat Ali\AppData\Local\Temp\ipykernel_12064\1482433130.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
clean_data_adult
# Out:
#        age     workclass  fnlwgt     education  educational_num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital_status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
clean_data_adult.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48790 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48790 non-null  int64
#  1   workclass        48790 non-null  object
#  2   fnlwgt           48790 non-null  int64
#  3   education        48790 non-null  object
#  4   educational_num  48790 non-null  int64
#  5   marital_status   48790 non-null  object
#  6   occupation       48790 non-null  object
#  7   relationship     48790 non-null  object
#  8   race             48790 non-null  object
#  9   gender           48790 non-null  object
#  10  capital_gain     48790 non-null  int64
#  11  capital_loss     48790 non-null  int64
#  12  hours_per_week   48790 non-null  int64
#  13  native_country   48790 non-null  object
#  14  income           48790 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 6.0+ MB

# %%
clean_data_adult.occupation.unique()
# Out:
# array(['Machine-op-inspct', 'Farming-fishing', 'Protective-serv', '?',
#        'Other-service', 'Prof-specialty', 'Craft-repair', 'Adm-clerical',
#        'Exec-managerial', 'Tech-support', 'Sales', 'Priv-house-serv',
#        'Transport-moving', 'Handlers-cleaners', 'Armed-Forces'],
#       dtype=object)

# %%
clean_data_adult.occupation.nunique()
# Out:
# 15

# %%
clean_data_adult.occupation.value_counts()
# Out:
# occupation
# Prof-specialty       6165
# Craft-repair         6102
# Exec-managerial      6082
# Adm-clerical         5606
# Sales                5501
# Other-service        4919
# Machine-op-inspct    3017
# ?                    2805
# Transport-moving     2355
# Handlers-cleaners    2071
# Farming-fishing      1485
# Tech-support         1445
# Protective-serv       982
# Priv-house-serv       240
# Armed-Forces           15
# Name: count, dtype: int64

# %%
clean_data_adult["occupation"] = clean_data_adult["occupation"].replace("?","unknown")
clean_data_adult.occupation.value_counts()
# Out:
# C:\Users\Shoukat Shadat Ali\AppData\Local\Temp\ipykernel_12064\628694062.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data_adult["occupation"] = clean_data_adult["occupation"].replace("?","unknown")
# occupation
# Prof-specialty       6165
# Craft-repair         6102
# Exec-managerial      6082
# Adm-clerical         5606
# Sales                5501
# Other-service        4919
# Machine-op-inspct    3017
# unknown              2805
# Transport-moving     2355
# Handlers-cleaners    2071
# Farming-fishing      1485
# Tech-support         1445
# Protective-serv       982
# Priv-house-serv       240
# Armed-Forces           15
# Name: count, dtype: int64

# %%
clean_data_adult.relationship.unique()
# Out:
# array(['Own-child', 'Husband', 'Not-in-family', 'Unmarried', 'Wife',
#        'Other-relative'], dtype=object)

# %%
clean_data_adult.relationship.nunique()
# Out:
# 6

# %%
clean_data_adult.relationship.value_counts()
# Out:
# relationship
# Husband           19703
# Not-in-family     12557
# Own-child          7569
# Unmarried          5124
# Wife               2331
# Other-relative     1506
# Name: count, dtype: int64

# %%
clean_data_adult.race.unique()
# Out:
# array(['Black', 'White', 'Asian-Pac-Islander', 'Other',
#        'Amer-Indian-Eskimo'], dtype=object)

# %%
clean_data_adult.race.nunique()
# Out:
# 5

# %%
clean_data_adult.race.value_counts()
# Out:
# race
# White                 41714
# Black                  4683
# Asian-Pac-Islander     1517
# Amer-Indian-Eskimo      470
# Other                   406
# Name: count, dtype: int64

# %%
clean_data_adult.gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
clean_data_adult.gender.nunique()
# Out:
# 2

# %%
clean_data_adult.gender.value_counts()
# Out:
# gender
# Male      32614
# Female    16176
# Name: count, dtype: int64

# %%
clean_data_adult.native_country.unique()
# Out:
# array(['United-States', '?', 'Peru', 'Guatemala', 'Mexico',
#        'Dominican-Republic', 'Ireland', 'Germany', 'Philippines',
#        'Thailand', 'Haiti', 'El-Salvador', 'Puerto-Rico', 'Vietnam',
#        'South', 'Columbia', 'Japan', 'India', 'Cambodia', 'Poland',
#        'Laos', 'England', 'Cuba', 'Taiwan', 'Italy', 'Canada', 'Portugal',
#        'China', 'Nicaragua', 'Honduras', 'Iran', 'Scotland', 'Jamaica',
#        'Ecuador', 'Yugoslavia', 'Hungary', 'Hong', 'Greece',
#        'Trinadad&Tobago', 'Outlying-US(Guam-USVI-etc)', 'France',
#        'Holand-Netherlands'], dtype=object)

# %%
clean_data_adult.native_country.nunique()
# Out:
# 42

# %%
clean_data_adult.native_country.value_counts()
# Out:
# native_country
# United-States                 43792
# Mexico                          943
# ?                               856
# Philippines                     294
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Poland                           87
# Guatemala                        86
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# ...

# %%
clean_data_adult.income.unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
clean_data_adult.income.nunique()
# Out:
# 2

# %%
clean_data_adult.income.value_counts()
# Out:
# income
# <=50K    37109
# >50K     11681
# Name: count, dtype: int64

# %%
clean_data_adult.age.min(), clean_data_adult.age.max(), clean_data_adult.age.mean()
# Out:
# (17, 90, np.float64(38.652797704447636))

# %%
clean_data_adult.fnlwgt.min(), clean_data_adult.fnlwgt.max(), clean_data_adult.fnlwgt.mean()
# Out:
# (12285, 1490400, np.float64(189668.9993646239))

# %%
clean_data_adult.educational_num.min(), clean_data_adult.educational_num.max(), clean_data_adult.educational_num.mean()
# Out:
# (1, 16, np.float64(10.07880713260914))

# %%
clean_data_adult.describe()
# Out:
#                 age        fnlwgt  educational_num  capital_gain  \
# count  48790.000000  4.879000e+04     48790.000000  48790.000000
# mean      38.652798  1.896690e+05        10.078807   1080.217688
# std       13.708493  1.056172e+05         2.570046   7455.905921
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175550e+05         9.000000      0.000000
# 50%       37.000000  1.781385e+05        10.000000      0.000000
# 75%       48.000000  2.376062e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital_loss  hours_per_week
# count  48790.000000    48790.000000
# mean      87.595573       40.425886
# std      403.209129       12.392729
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
clean_data_adult.capital_gain.min(), clean_data_adult.capital_gain.max(), clean_data_adult.capital_gain.mean()
# Out:
# (0, 99999, np.float64(1080.21768805083))

# %%
clean_data_adult.capital_loss.min(), clean_data_adult.capital_loss.max(), clean_data_adult.capital_loss.mean()
# Out:
# (0, 4356, np.float64(87.59557286329166))

# %%
plt.hist(clean_data_adult.age)
# Out:
# (array([8409., 8673., 9117., 9148., 5962., 3876., 2456.,  777.,  277.,
#           95.]),
#  array([17. , 24.3, 31.6, 38.9, 46.2, 53.5, 60.8, 68.1, 75.4, 82.7, 90. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(clean_data_adult[clean_data_adult.gender == "Male"]["age"])
# Out:
# (array([4599., 5662., 6459., 6441., 4233., 2763., 1693.,  507.,  193.,
#           64.]),
#  array([17. , 24.3, 31.6, 38.9, 46.2, 53.5, 60.8, 68.1, 75.4, 82.7, 90. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(clean_data_adult[clean_data_adult.gender == "Female"]["age"])
# Out:
# (array([3810., 3011., 2658., 2707., 1729., 1113.,  763.,  270.,   84.,
#           31.]),
#  array([17. , 24.3, 31.6, 38.9, 46.2, 53.5, 60.8, 68.1, 75.4, 82.7, 90. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(7,2))
plt.hist(clean_data_adult[clean_data_adult.gender == "Male"]["age"])
plt.show()

# %%
plt.figure(figsize=(7,2))
plt.hist(clean_data_adult[clean_data_adult.gender == "Female"]["age"])
plt.show()

# %%
clean_data_adult[["gender","age"]].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='gender,age'>

# %%
clean_data_adult["age_group"] = pd.cut(clean_data_adult.age,bins=[30,50,70,90,100],
                                      labels=["young","matured","old","older"])
age_group_Freq = clean_data_adult.age_group.value_counts()
# Out:
# C:\Users\Shoukat Shadat Ali\AppData\Local\Temp\ipykernel_12064\306498170.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data_adult["age_group"] = pd.cut(clean_data_adult.age,bins=[30,50,70,90,100],

# %%
age_group_Freq
# Out:
# age_group
# young      23225
# matured     8940
# old          867
# older          0
# Name: count, dtype: int64

# %%
age_group_Freq.plot(kind="barh")
# Out:
# <Axes: ylabel='age_group'>

# %%
clean_data_adult[["gender","income"]].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='gender,income'>

# %%
clean_data_adult.gender.value_counts().plot(kind="pie", autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
clean_data_adult.income.value_counts().plot(kind="pie", autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
clean_data_adult.native_country.value_counts().plot(kind="pie", autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
clean_data_adult.native_country.value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='native_country'>

# %%
import numpy as np

# %%
clean_data_adult["native_country_group"] = np.where(clean_data_adult["native_country"] == "United-States", "USA", "non_USA")
# Out:
# C:\Users\Shoukat Shadat Ali\AppData\Local\Temp\ipykernel_12064\3770505748.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data_adult["native_country_group"] = np.where(clean_data_adult["native_country"] == "United-States", "USA", "non_USA")

# %%
clean_data_adult.native_country_group.value_counts()
# Out:
# native_country_group
# USA        43792
# non_USA     4998
# Name: count, dtype: int64

# %%
clean_data_adult[["native_country_group","income"]].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='native_country_group,income'>

# %%
clean_data_adult["workclass"] = clean_data_adult["workclass"].replace("?","unknown")
# Out:
# C:\Users\Shoukat Shadat Ali\AppData\Local\Temp\ipykernel_12064\4000092494.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data_adult["workclass"] = clean_data_adult["workclass"].replace("?","unknown")

# %%
clean_data_adult.workclass.value_counts()
# Out:
# workclass
# Private             33860
# Self-emp-not-inc     3861
# Local-gov            3136
# unknown              2795
# State-gov            1981
# Self-emp-inc         1694
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
clean_data_adult[["workclass","income"]].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='workclass,income'>

# %%
clean_data_adult[["workclass","native_country_group"]].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='workclass,native_country_group'>

# %%
clean_data_adult["fnlwgt_group"] = pd.cut(clean_data_adult.fnlwgt,bins=5, labels=["very_low","low","medium","heavy", "extra-heavy"])
clean_data_adult.fnlwgt_group.value_counts()
# Out:
# C:\Users\Shoukat Shadat Ali\AppData\Local\Temp\ipykernel_12064\1085862939.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data_adult["fnlwgt_group"] = pd.cut(clean_data_adult.fnlwgt,bins=5, labels=["very_low","low","medium","heavy", "extra-heavy"])
# fnlwgt_group
# very_low       42684
# low             5891
# medium           186
# heavy             22
# extra-heavy        7
# Name: count, dtype: int64

# %%
clean_data_adult[["gender","fnlwgt_group"]].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='gender,fnlwgt_group'>

# %%
clean_data_adult[["fnlwgt_group","income"]].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='fnlwgt_group,income'>

# %%
clean_data_adult[["marital_status","income"]].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='marital_status,income'>

# %%
clean_data_adult[["education","income"]].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='education,income'>

# %%
clean_data_adult.hours_per_week
# Out:
# 0        40
# 1        50
# 2        40
# 3        40
# 4        30
#          ..
# 48837    38
# 48838    40
# 48839    40
# 48840    20
# 48841    40
# Name: hours_per_week, Length: 48790, dtype: int64

# %%
clean_data_adult["hours_per_week_group"] = pd.cut(clean_data_adult.hours_per_week,bins=5, labels=["very_low","low","medium","heavy", "extra-heavy"])
clean_data_adult.hours_per_week_group.value_counts()
# Out:
# C:\Users\Shoukat Shadat Ali\AppData\Local\Temp\ipykernel_12064\3955839539.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_data_adult["hours_per_week_group"] = pd.cut(clean_data_adult.hours_per_week,bins=5, labels=["very_low","low","medium","heavy", "extra-heavy"])
# hours_per_week_group
# low            30001
# medium         10490
# very_low        4446
# heavy           3325
# extra-heavy      528
# Name: count, dtype: int64

# %%
clean_data_adult[["hours_per_week_group","income"]].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='hours_per_week_group,income'>

# %%
clean_data_adult[["hours_per_week_group","gender"]].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='hours_per_week_group,gender'>

# %% [markdown]
# # Data File: hotel_booking.csv

# %%
hotel_booking_data = pd.read_csv(r"G:\Jupyter Notebook\Practice Data Files\hotel_booking.csv")
hotel_booking_data
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
hotel_booking_data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
hotel_booking_data.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
hotel_booking_data.shape
# Out:
# (119390, 36)

# %%
hotel_booking_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
hotel_booking_data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
hotel_booking_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
hotel_booking_data.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
hotel_booking_data['children'] = hotel_booking_data['children'].fillna(0)
hotel_booking_data['country'] = hotel_booking_data['country'].fillna("unknown")
hotel_booking_data['agent'] = hotel_booking_data['agent'].fillna("unknown")
hotel_booking_data['company'] = hotel_booking_data['company'].fillna("unknown")

# %%
hotel_booking_data.isna().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
hotel_booking_data.hotel.value_counts()
# Out:
# hotel
# City Hotel      79330
# Resort Hotel    40060
# Name: count, dtype: int64

# %%
hotel_booking_data.meal.value_counts()
# Out:
# meal
# BB           92310
# HB           14463
# SC           10650
# Undefined     1169
# FB             798
# Name: count, dtype: int64

# %%
hotel_booking_data.country.value_counts()
# Out:
# country
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: count, Length: 178, dtype: int64

# %%
hotel_booking_data.market_segment.value_counts()
# Out:
# market_segment
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: count, dtype: int64

# %%
hotel_booking_data.distribution_channel.value_counts()
# Out:
# distribution_channel
# TA/TO        97870
# Direct       14645
# Corporate     6677
# GDS            193
# Undefined        5
# Name: count, dtype: int64

# %%
hotel_booking_data.arrival_date_year.value_counts()
# Out:
# arrival_date_year
# 2016    56707
# 2017    40687
# 2015    21996
# Name: count, dtype: int64

# %%
hotel_booking_data.arrival_date_month.value_counts()
# Out:
# arrival_date_month
# August       13877
# July         12661
# May          11791
# October      11160
# April        11089
# June         10939
# September    10508
# March         9794
# February      8068
# November      6794
# December      6780
# January       5929
# Name: count, dtype: int64

# %%
hotel_booking_data.is_repeated_guest.value_counts()
# Out:
# is_repeated_guest
# 0    115580
# 1      3810
# Name: count, dtype: int64

# %%
hotel_booking_data.reserved_room_type.value_counts()
# Out:
# reserved_room_type
# A    85994
# D    19201
# E     6535
# F     2897
# G     2094
# B     1118
# C      932
# H      601
# P       12
# L        6
# Name: count, dtype: int64

# %%
hotel_booking_data.assigned_room_type.value_counts()
# Out:
# assigned_room_type
# A    74053
# D    25322
# E     7806
# F     3751
# G     2553
# C     2375
# B     2163
# H      712
# I      363
# K      279
# P       12
# L        1
# Name: count, dtype: int64

# %%
hotel_booking_data.booking_changes.value_counts()
# Out:
# booking_changes
# 0     101314
# 1      12701
# 2       3805
# 3        927
# 4        376
# 5        118
# 6         63
# 7         31
# 8         17
# 9          8
# 10         6
# 13         5
# 14         5
# 15         3
# 16         2
# 17         2
# 12         2
# 11         2
# 20         1
# 21         1
# 18         1
# Name: count, dtype: int64

# %%
hotel_booking_data.deposit_type.value_counts()
# Out:
# deposit_type
# No Deposit    104641
# Non Refund     14587
# Refundable       162
# Name: count, dtype: int64

# %%
hotel_booking_data.agent.value_counts()
# Out:
# agent
# 9.0        31961
# unknown    16340
# 240.0      13922
# 1.0         7191
# 14.0        3640
#            ...
# 280.0          1
# 285.0          1
# 289.0          1
# 265.0          1
# 497.0          1
# Name: count, Length: 334, dtype: int64

# %%
hotel_booking_data.company.value_counts()
# Out:
# company
# unknown    112593
# 40.0          927
# 223.0         784
# 67.0          267
# 45.0          250
#             ...
# 32.0            1
# 11.0            1
# 487.0           1
# 101.0           1
# 376.0           1
# Name: count, Length: 353, dtype: int64

# %%
hotel_booking_data.customer_type.value_counts()
# Out:
# customer_type
# Transient          89613
# Transient-Party    25124
# Contract            4076
# Group                577
# Name: count, dtype: int64

# %%
hotel_booking_data.reservation_status.value_counts()
# Out:
# reservation_status
# Check-Out    75166
# Canceled     43017
# No-Show       1207
# Name: count, dtype: int64

# %%
hotel_booking_data.name
# Out:
# 0              Ernest Barnes
# 1               Andrea Baker
# 2             Rebecca Parker
# 3               Laura Murray
# 4                Linda Hines
#                  ...
# 119385       Claudia Johnson
# 119386        Wesley Aguilar
# 119387          Mary Morales
# 119388    Caroline Conley MD
# 119389        Ariana Michael
# Name: name, Length: 119390, dtype: object

# %%
hotel_booking_data.email
# Out:
# 0         Ernest.Barnes31@outlook.com
# 1              Andrea_Baker94@aol.com
# 2          Rebecca_Parker@comcast.net
# 3                   Laura_M@gmail.com
# 4                  LHines@verizon.com
#                      ...
# 119385            Claudia.J@yahoo.com
# 119386           WAguilar@xfinity.com
# 119387       Mary_Morales@hotmail.com
# 119388        MD_Caroline@comcast.net
# 119389           Ariana_M@xfinity.com
# Name: email, Length: 119390, dtype: object

# %%
hotel_booking_data.rename(columns={"phone-number":"phone_number"})
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
hotel_booking_data.required_car_parking_spaces.value_counts()
# Out:
# required_car_parking_spaces
# 0    111974
# 1      7383
# 2        28
# 3         3
# 8         2
# Name: count, dtype: int64

# %%
hotel_booking_data.total_of_special_requests.value_counts()
# Out:
# total_of_special_requests
# 0    70318
# 1    33226
# 2    12969
# 3     2497
# 4      340
# 5       40
# Name: count, dtype: int64

# %%
hotel_booking_data["is_repeated_guest"] = hotel_booking_data["is_repeated_guest"].replace({0:"no", 1: "yes"})

# %%
hotel_booking_data.is_repeated_guest.value_counts()
# Out:
# is_repeated_guest
# no     115580
# yes      3810
# Name: count, dtype: int64

# %%
hotel_booking_data.hotel.value_counts().plot(kind="pie", autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
hotel_booking_data.meal.value_counts().plot(kind="pie", autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
hotel_booking_data.meal.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='meal'>

# %%
hotel_booking_data.market_segment.value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='market_segment'>

# %%
hotel_booking_data.distribution_channel.value_counts().plot(kind="pie", autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
hotel_booking_data.distribution_channel.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='distribution_channel'>

# %%
hotel_booking_data.arrival_date_year.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='arrival_date_year'>

# %%
hotel_booking_data.arrival_date_year.value_counts().plot(kind="pie", autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
hotel_booking_data.arrival_date_month.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='arrival_date_month'>

# %%
hotel_booking_data.is_repeated_guest.value_counts().plot(kind="pie", autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
hotel_booking_data.reserved_room_type.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='reserved_room_type'>

# %%
hotel_booking_data.assigned_room_type.value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='assigned_room_type'>

# %%
hotel_booking_data.deposit_type.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='deposit_type'>

# %%
hotel_booking_data.customer_type.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='customer_type'>

# %%
hotel_booking_data.reservation_status.value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='reservation_status'>

# %%
hotel_booking_data.reservation_status.value_counts().plot(kind="pie", autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
hotel_booking_data.required_car_parking_spaces.value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='required_car_parking_spaces'>

# %%
hotel_booking_data.required_car_parking_spaces.value_counts().plot(kind="pie", autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
hotel_booking_data.total_of_special_requests.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='total_of_special_requests'>

# %%
hotel_booking_data.total_of_special_requests.value_counts().plot(kind="pie", autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>
